# %%
pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.5.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444327 sha256=1374b533d5051baae6c7434908d4b76270621c8177941ecf4159c331579299be
#   Stored in directory: /root/.cache/pip/wheels/82/b7/03/8344d8cf6695624746311bc0d389e9d05535ca83c35f90241d
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.5.0

# %%
from scapy.all import *

# %%
def packet_callback(packet):
  if packet.haslayer(IP):
    src_ip = packet[IP].src
    dst_ip = packet[IP].dst
    protocol = packet[IP].proto
    print(f"IP Packet: {src_ip} --> {dst_ip} Protocol: {protocol}")
  if packet.haslayer(TCP):
    src_port = packet[TCP].sport
    dst_port = packet[TCP].dport
    print(f"TCP Packet: {src_port} --> {dst_port}")
  if packet.haslayer(UDP):
    src_port = packet[UDP].sport
    dst_port = packet[UDP].dport
    print(f"UDP Packet: {src_port} --> {dst_port}")

#Sniff all incoming and outgoing packets
sniff(prn=packet_callback, store=0)
# Out:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38746 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38746
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 41782
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 41782
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 38734
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 38734 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35720 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35720
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 41782
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 35730
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 35730 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 46058
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 46058 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 41782
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 41782
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 41782 --> 6000
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56844 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56844
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 36994
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 36994 --> 8080
# <Sniffed: TCP:0 UDP:0 ICMP:0 Other:0>
